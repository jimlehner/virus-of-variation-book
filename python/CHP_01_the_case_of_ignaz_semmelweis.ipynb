# %% [markdown]
# # Chapter 1: The case of Ignaz Semmelweis
#
# For additional context see Chapter 1 of [The Virus of Variation](https://www.brokenquality.com/book).
# Questions? Email us at James.Lehner@gmail.com or QualityIsBroken@gmail.com

# %%
# Import libraries
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %matplotlib inline

# %% [markdown]
# ## Get the data
#
# The dataset used in this chapter is called:
#
# `vienna-general-death-to-birth-rates-by-clinic.csv`
#
# The data can be found at https://github.com/jimlehner/virus-of-variation-book/tree/main/data.

# %%
# Establish the dataset_url
dataset_url = r'https://raw.githubusercontent.com/jimlehner/virus-of-variation-book/refs/heads/main/data/vienna-general-death-to-birth-rates-by-clinic.csv'

# Get data function
def get_data(dataset_url) -> pd.DataFrame:
    return pd.read_csv(dataset_url)

# Get data
df = get_data(dataset_url)
df.head()
# Out:
#                   Hospital      Clinic            Employee  \
# 0  Vienna General Hospital  1st Clinic  Students & Doctors
# 1  Vienna General Hospital  1st Clinic  Students & Doctors
# 2  Vienna General Hospital  1st Clinic  Students & Doctors
# 3  Vienna General Hospital  1st Clinic  Students & Doctors
# 4  Vienna General Hospital  1st Clinic  Students & Doctors
#
#                 Stage  Year  Births  Deaths  Rate                   Note
# 0  Before handwashing  1833    3737     197   5.3  Second clinic started
# 1  Before handwashing  1834    2657     205   7.7                    NaN
# 2  Before handwashing  1835    2573     143   5.6                    NaN
# 3  Before handwashing  1836    2677     200   7.5                    NaN
# 4  Before handwashing  1837    2765     251   9.1                    NaN

# %% [markdown]
# ## Sub-select df to get 1846 data

# %%
# Create df_1846
df_1846 = df[df['Year'] == 1846].reset_index(drop=True)
df_1846
# Out:
#                   Hospital      Clinic            Employee  \
# 0  Vienna General Hospital  1st Clinic  Students & Doctors
# 1  Vienna General Hospital  2nd Clinic            Midwives
#
#                 Stage  Year  Births  Deaths  Rate Note
# 0  Before handwashing  1846    4010     459  11.4  NaN
# 1  Before handwashing  1846    3754     105   2.8  NaN

# %% [markdown]
# ## Fig 1.1. Bar chart of death-to-birth rates by clinic at Vienna General Hospital in 1846

# %%
# Create custom label for bar chart x-axis
labels = pd.Series(
    ['Clinic run by students & doctors\n(1st Clinic)',
     'Clinic run by midwives\n(2nd Clinic)']
)

# Create bar chart
fig,ax = plt.subplots(figsize=(12,3), dpi=500)

barplot = sns.barplot(x=labels, 
                      y=df_1846['Rate'], 
                      color='tab:blue', 
                      width=0.25)

# Add labels on top of the bars
for bar in ax.patches:
    height = bar.get_height()
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        height,
        f'{height:.1f}%',
        ha='center', 
        va='bottom',
        fontsize=12,
        color='black'
    )

# Formatting
ax.tick_params(axis='x', labelsize=12)
ax.set_yticks([])
ax.set_ylabel('')

# Despine plot
sns.despine(left=True)

# Show plot
plt.show()
