# %% [markdown]
# # Appendix G.2 Vienna General physical comparison calculations

# %%
# Import libraries
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

from process_improvement.charts.xmr_charts import xmr_chart
from process_improvement.charts.utils import XmRChartConfig

# %matplotlib inline

# %% [markdown]
# ## Step 1. Gather the data

# %%
# Get data
def get_data(dataset_url) -> pd.DataFrame:
    return pd.read_csv(dataset_url)

# Vienna url
rates_url = r'https://raw.githubusercontent.com/jimlehner/virus-of-variation-book/refs/heads/main/data/physical-comparison-death-to-birth-rates.csv'
# Vienna General dataset url
rates_df = get_data(rates_url)

# Show first 10 lines of rates_df
rates_df.head(10)

# Show columns
rates_df.columns
# Out:
# Index(['Hospital', 'Year', 'Births', 'Deaths', 'Rate', 'Note'], dtype='object')

# %% [markdown]
# ### Drop  unnecessary columns from dataframe

# %%
rates_df = rates_df[['Hospital', 
           'Year', 
           #'Births', 
           #'Deaths', 
           'Rate', 
           #'Note'
          ]]

# Make 'Year' column dtype string
rates_df['Year'] = rates_df['Year'].astype('string')

# Show dataframe dtypes
rates_df.dtypes
# Out:
# Hospital            object
# Year        string[python]
# Rate               float64
# dtype: object

# %% [markdown]
# ### Splite dataframe according to stage

# %%
dublin_df = rates_df[rates_df['Hospital'] == 'Dublin Maternity Hospital'].copy()
vienna_df = rates_df[rates_df['Hospital'] == 'Vienna General Hospital'].reset_index(drop=True)

# %% [markdown]
# ## Step 2. Calculate the moving ranges

# %%
# Calculate the moving ranges for before_df
vienna_df['Moving Ranges'] = abs(vienna_df['Rate'].diff())
vienna_df
# Out:
#                    Hospital  Year  Rate  Moving Ranges
# 0   Vienna General Hospital  1784   2.1            NaN
# 1   Vienna General Hospital  1785   1.4            0.7
# 2   Vienna General Hospital  1786   0.4            1.0
# 3   Vienna General Hospital  1787   0.4            0.0
# 4   Vienna General Hospital  1788   0.4            0.0
# 5   Vienna General Hospital  1789   0.6            0.2
# 6   Vienna General Hospital  1790   0.8            0.2
# 7   Vienna General Hospital  1791   0.6            0.2
# 8   Vienna General Hospital  1792   0.9            0.3
# 9   Vienna General Hospital  1793   2.6            1.7
# 10  Vienna General Hospital  1794   0.4            2.2
# 11  Vienna General Hospital  1795   2.1            1.7
# 12  Vienna General Hospital  1796   1.2            0.9
# 13  Vienna General Hospital  1797   0.2            1.0
# 14  Vienna General Hospital  1798   0.2            0.0
# 15  Vienna General Hospital  1799   1.0            0.8
# 16  Vienna General Hospital  1800   2.0            1.0
# 17  Vienna General Hospital  1801   0.8            1.2
# 18  Vienna General Hospital  1802   0.4            0.4
# 19  Vienna General Hospital  1803   0.7            0.3
# 20  Vienna General Hospital  1804   0.4            0.3
# 21  Vienna General Hospital  1805   0.4            0.0
# 22  Vienna General Hospital  1806   0.7            0.3
# 23  Vienna General Hospital  1807   0.6            0.1
# 24  Vienna General Hospital  1808   0.8            0.2
# 25  Vienna General Hospital  1809   1.4            0.6
# 26  Vienna General Hospital  1810   0.8            0.6
# 27  Vienna General Hospital  1811   1.9            1.1
# 28  Vienna General Hospital  1812   0.6            1.3
# 29  Vienna General Hospital  1813   1.1            0.5
# 30  Vienna General Hospital  1814   3.2            2.1
# 31  Vienna General Hospital  1815   0.7            2.5
# 32  Vienna General Hospital  1816   0.5            0.2
# 33  Vienna General Hospital  1817   0.9            0.4
# 34  Vienna General Hospital  1818   2.2            1.3
# 35  Vienna General Hospital  1819   5.0            2.8
# 36  Vienna General Hospital  1820   2.5            2.5
# 37  Vienna General Hospital  1821   1.7            0.8
# 38  Vienna General Hospital  1822   0.8            0.9
# 39  Vienna General Hospital  1823   7.5            6.7
# 40  Vienna General Hospital  1824   4.9            2.6
# 41  Vienna General Hospital  1825   8.8            3.9
# 42  Vienna General Hospital  1826   8.1            0.7
# 43  Vienna General Hospital  1827   2.2            5.9
# 44  Vienna General Hospital  1828   3.6            1.4
# 45  Vienna General Hospital  1829   4.6            1.0
# 46  Vienna General Hospital  1830   4.0            0.6
# 47  Vienna General Hospital  1831   6.6            2.6
# 48  Vienna General Hospital  1832   3.2            3.4
# 49  Vienna General Hospital  1833   5.3            2.1
# 50  Vienna General Hospital  1834   7.7            2.4
# 51  Vienna General Hospital  1835   5.6            2.1
# 52  Vienna General Hospital  1836   7.5            1.9
# 53  Vienna General Hospital  1837   9.1            1.6
# 54  Vienna General Hospital  1838   3.0            6.1
# 55  Vienna General Hospital  1839   5.4            2.4
# 56  Vienna General Hospital  1840   9.2            3.8

# %% [markdown]
# ## Step 3. Calculate the average moving range

# %%
# Calculate the average moving range for before_df['Moving Ranges']
vienna_ave_mR = round(vienna_df['Moving Ranges'].mean(),2)
vienna_ave_mR
# Out:
# 1.49

# %% [markdown]
# ## Step 4. Calculate the mean

# %%
# Calculate the mean before_df['Rate']
vienna_mean = round(vienna_df['Rate'].mean(),2)
vienna_mean
# Out:
# 2.66

# %% [markdown]
# ## Step 5. Calculate the process limits

# %%
# Upper Process Limit (UPL)
vienna_UPL = round(vienna_mean + (2.660*vienna_ave_mR),2)
# Lower Process Limit (LPL)
vienna_LPL = round(vienna_mean - (2.660*vienna_ave_mR),2)
# Upper Process Limit (UPL)
vienna_URL = round(3.268*vienna_ave_mR,2)
# Show results
print('UPL:', vienna_UPL)
print('LPL:', vienna_LPL)
print('URL:', vienna_URL)
# Out:
# UPL: 6.62
# LPL: -1.3
# URL: 4.87

# %% [markdown]
# ## Step 6. Put it all together

# %%
XmRConfig = XmRChartConfig(label_fontsize=14,
                          xtick_fontsize=12,
                          tickinterval=5,
                          round_value=2,
                          xchart_ylabel="Death-to-Birth Rate (%)")

vienna_results = xmr_chart(vienna_df,
                           'Rate',
                           'Year', 
                           config=XmRConfig)

# %%
vienna_results.stats_df
# Out:
#       Chart     Process Stats         Values
# 0   X chart              Mean           2.66
# 1   X chart               UPL           6.62
# 2   X chart               LPL            0.0
# 3   X chart               PLR           7.93
# 4  mR chart           Ave. mR           1.49
# 5  mR chart               URL           4.87
# 6            Characterization  Unpredictable
